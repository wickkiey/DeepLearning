# %%
import tensorflow as tf  
import numpy as np
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import cv2
import os
import PIL.Image as Image

# %%
# %matplotlib inline

# %%
model_path = "https://tfhub.dev/captain-pool/esrgan-tf2/1"

# %%
IMAGE_SHAPE = (180,320)

# %%
image = cv2.imread("lion.jpg")
image.shape
# Out:
# (455, 728, 3)

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (IMAGE_SHAPE[1], IMAGE_SHAPE[0]))

# %%
model  = tf.keras.Sequential([
    hub.KerasLayer(model_path, input_shape=IMAGE_SHAPE+(3,))
])

# %%
model(np.array([image])/255.0).shape
# Out:
# 2023-05-20 10:40:35.380760: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# TensorShape([1, 720, 1280, 3])

# %%
out_image = model(np.array([image])/255.0)[0]

# %%
plt.imshow(out_image)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(image)

# %%
upscaled_image = cv2.resize(image, (IMAGE_SHAPE[1]*4, IMAGE_SHAPE[0]*4))

# %%
plt.imshow(upscaled_image)
