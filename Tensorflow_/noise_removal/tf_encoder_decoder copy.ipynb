# %%
import tensorflow as tf

from tensorflow.keras.datasets import fashion_mnist

import matplotlib.pyplot as plt

import os 

import numpy as np

from tensorflow.data import AUTOTUNE

# %%
# (xtrain,_), (xtest,_) = fashion_mnist.load_data()

# %%
data_dir = r"D:\digital_enhancement\images\kk"
images = os.listdir(data_dir)
images_list = [data_dir + "/" + img for img in images]
image_count = len(images_list)

# %%
list_ds = tf.data.Dataset.list_files(images_list, shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(5):
  print(f.numpy())
# Out:
# b'D:\\digital_enhancement\\images\\kk\\image_2900.jpg'
# b'D:\\digital_enhancement\\images\\kk\\image_1880.jpg'
# b'D:\\digital_enhancement\\images\\kk\\image_4510.jpg'
# b'D:\\digital_enhancement\\images\\kk\\image_7030.jpg'
# b'D:\\digital_enhancement\\images\\kk\\image_21100.jpg'

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %%
width = 640
height = 360
noise_factor = .2

# %%
def decode_img(img):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=3)
  # Resize the image to the desired size
  img = tf.image.resize(img, [height, width])
  # img = tf.cast(img, tf.float32) / 255.0
  # img = noise_factor * tf.random.normal(shape=tf.shape(img))
  # img = tf.clip_by_value(img, clip_value_min=0., clip_value_max=1.) 
  return img

def process_path(file_path):
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, img


train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(4)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(4):
  ax = plt.subplot(3, 3, i + 1)
  img = image_batch[i].numpy().astype("uint8")
  print(img.max())
  # img *= 255
  # i = i.astype("uint8")
  plt.imshow(img)
#   label = label_batch[i]
  plt.title("img")
  plt.axis("off")
# Out:
# 255
# 255
# 254
# 254

# %%
# Build encoder decoder model using keras functional API

from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, BatchNormalization, UpSampling2D, GaussianNoise
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

def create_model():
  x = Input(shape=(height, width, 3))
# Encoder
  # noise = GaussianNoise(0.6)(x)
  e_conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
  pool1 = MaxPooling2D((2, 2), padding='same')(e_conv1)
  batchnorm_1 = BatchNormalization()(pool1)
  e_conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(batchnorm_1)
  pool2 = MaxPooling2D((2, 2), padding='same')(e_conv2)
  batchnorm_2 = BatchNormalization()(pool2)
  e_conv3 = Conv2D(16, (3, 3), activation='relu', padding='same')(batchnorm_2)
  h = MaxPooling2D((2, 2), padding='same')(e_conv3)
# Decoder
  d_conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(h)
  up1 = UpSampling2D((2, 2))(d_conv1)
  d_conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(up1)
  up2 = UpSampling2D((2, 2))(d_conv2)
  d_conv3 = Conv2D(16, (3, 3), activation='relu', padding='same')(up2)
  up3 = UpSampling2D((2, 2))(d_conv3)
  r = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(up3)
  
  model = Model(x, r)
  model.compile(optimizer='adam', loss='mse')
  return model
gaussian_auto_encoder = create_model()
gaussian_early_stop = EarlyStopping(monitor='loss', patience=3)
gaussian_history = gaussian_auto_encoder.fit(train_ds,validation_data= val_ds, epochs=20, batch_size=32, callbacks=[gaussian_early_stop])
# Out:
# Epoch 1/20
# 462/462 [==============================] - 36s 55ms/step - loss: 0.0539 - val_loss: 0.0530
# Epoch 2/20
# 462/462 [==============================] - 24s 51ms/step - loss: 0.0530 - val_loss: 0.0529
# Epoch 3/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0529 - val_loss: 0.0529
# Epoch 4/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0529 - val_loss: 0.0529
# Epoch 5/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0529 - val_loss: 0.0529
# Epoch 6/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0529 - val_loss: 0.0529
# Epoch 7/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0529 - val_loss: 0.0529
# Epoch 8/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0529
# Epoch 9/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0530
# Epoch 10/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0529
# Epoch 11/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0529
# Epoch 12/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0528
# Epoch 13/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0528
# Epoch 14/20
# 462/462 [==============================] - 24s 53ms/step - loss: 0.0528 - val_loss: 0.0528
# Epoch 15/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0528
# Epoch 16/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0528
# Epoch 17/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0528
# Epoch 18/20
# 462/462 [==============================] - 24s 52ms/step - loss: 0.0528 - val_loss: 0.0527
# Epoch 19/20
# 462/462 [==============================] - 25s 54ms/step - loss: 0.0528 - val_loss: 0.0529
# Epoch 20/20
#  13/462 [..............................] - ETA: 22s - loss: 0.0527
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31436\2597896025.py in <module>
#      31 gaussian_auto_encoder = create_model()
#      32 gaussian_early_stop = EarlyStopping(monitor='loss', patience=3)
# ---> 33 gaussian_history = gaussian_auto_encoder.fit(train_ds,validation_data= val_ds, epochs=20, batch_size=32, callbacks=[gaussian_early_stop])
#      34
#      35
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568                             logs = tmp_logs
#    1569                             end_step = step + data_handler.step_increment
# -> 1570                             callbacks.on_train_batch_end(end_step, logs)
#    1571                             if self.stop_training:
#    1572                                 break
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     468         """
#     469         if self._should_call_train_batch_hooks:
# --> 470             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     471
#     472     def on_test_batch_begin(self, batch, logs=None):
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     315             self._call_batch_begin_hook(mode, batch, logs)
#     316         elif hook == "end":
# --> 317             self._call_batch_end_hook(mode, batch, logs)
#     318         else:
#     319             raise ValueError(
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     338             self._batch_times.append(batch_time)
#     339
# --> 340         self._call_batch_hook_helper(hook_name, batch, logs)
#     341
#     342         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     386         for callback in self.callbacks:
#     387             hook = getattr(callback, hook_name)
# --> 388             hook(batch, logs)
#     389
#     390         if self._check_timing:
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1079
#    1080     def on_train_batch_end(self, batch, logs=None):
# -> 1081         self._batch_update_progbar(batch, logs)
#    1082
#    1083     def on_test_batch_end(self, batch, logs=None):
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1155         if self.verbose == 1:
#    1156             # Only block async when verbose = 1.
# -> 1157             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1159
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     633         return t.item() if np.ndim(t) == 0 else t
#     634
# --> 635     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     636
#     637
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     626         # Don't turn ragged or sparse tensors to NumPy.
#     627         if isinstance(t, tf.Tensor):
# --> 628             t = t.numpy()
#     629         # Strings, ragged and sparse tensors don't have .item(). Return them
#     630         # as-is.
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1155     """
#    1156     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1159
#
# c:\Users\vivek\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1121   def _numpy(self):
#    1122     try:
# -> 1123       return self._numpy_internal()
#    1124     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(4):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image_batch[i].numpy().astype("uint8"))
#   label = label_batch[i]
  plt.title("img")
  plt.axis("off")

# %%
i = next(iter(val_ds))

# %%
i[0][:1].shape
# Out:
# TensorShape([1, 640, 360, 3])

# %%
encoded_imgs=gaussian_auto_encoder.encoder(i[0][""]).numpy()
decoded_imgs=gaussian_auto_encoder.decoder(encoded_imgs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25516\3542346341.py in <module>
# ----> 1 encoded_imgs=gaussian_auto_encoder.encoder(i[0][""]).numpy()
#       2 decoded_imgs=gaussian_auto_encoder.decoder(encoded_imgs)
#
# AttributeError: 'Functional' object has no attribute 'encoder'

# %%
o = gaussian_auto_encoder.predict(i[0][:1])
o.shape
# Out:
# 1/1 [==============================] - 0s 73ms/step
# (1, 640, 360, 3)

# %%
plt.imshow(o[0]*255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
n = 10 
plt.figure(figsize=(20, 7))
plt.gray()

for i in range(n): 
  # display original + noise 
  bx = plt.subplot(3, n, i + 1) 
  plt.title("original + noise") 
  plt.imshow(tf.squeeze(x_test_noisy[i])) 
  ax.get_xaxis().set_visible(False) 
  ax.get_yaxis().set_visible(False) 
  
  # display reconstruction 
  cx = plt.subplot(3, n, i + n + 1) 
  plt.title("reconstructed") 
  plt.imshow(tf.squeeze(decoded_imgs[i])) 
  bx.get_xaxis().set_visible(False) 
  bx.get_yaxis().set_visible(False) 
  
  # display original 
  ax = plt.subplot(3, n, i + 2*n + 1) 
  plt.title("original") 
  plt.imshow(tf.squeeze(x_test[i])) 
  ax.get_xaxis().set_visible(False) 
  ax.get_yaxis().set_visible(False) 

plt.show()
