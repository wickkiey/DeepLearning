# %%
import tensorflow as tf 
import tensorflow_addons as tfa 
import numpy as np 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Read Image 

# img = tf.io.decode_jpeg(tf.io.read_file('D:\digital_enhancement\images\kk\image_170.jpg'))
path = r'D:\data\cartoonset10k_rgb\cs10000053986926948907.jpg'
img = tf.io.decode_jpeg(tf.io.read_file('D:\data\cartoonset10k_rgb\cs10000053986926948907.jpg'))
# img = tf.image.resize(img,[72*2,128*2])
# img = img[tf.newaxis,...]
# img.shape

# %%
image = tf.keras.preprocessing.image.load_img(path)

# Convert the image to a tensor and preprocess it
image_tensor = tf.keras.preprocessing.image.img_to_array(image)

# %%
type(image), type(image_tensor)
# Out:
# (PIL.JpegImagePlugin.JpegImageFile, numpy.ndarray)

# %%
type(img)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
# Out:
# array([[[[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
# ...

# %%
img = tf.cast(img, tf.float32) / 255.

# %%
img.dtype
# Out:
# tf.float32

# %%
# Conv 2d
print("Input Image Shape: ", img.shape)
conv2d = tf.keras.layers.Conv2D(3, 31, activation='relu',input_shape=(None, None, 3))
out = conv2d(img)

# for i in range(2):
#     out = conv2d(out)

print("Output Image Shape: ", out.shape)
# plt.imshow(out.numpy())
# Out:
# Input Image Shape:  (1, 144, 256, 3)
# Output Image Shape:  (1, 114, 226, 3)

# %%
plt.imshow(out[0].numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(img[0].numpy())
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
