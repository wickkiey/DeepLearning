# %%
import torch 
import torch.nn as nn
import matplotlib.pyplot as plt
from torchvision import transforms

# %%
from PIL import Image

# %%
img = Image.open("D:/data/images/elephant.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=364x280 at 0x21E969462E0>

# %%
img_tensor = transforms.ToTensor()(np.img)
img_tensor.shape
# Out:
# torch.Size([3, 280, 364])

# %%
# define Transformed convolution

ct2d  = nn.ConvTranspose2d(3,3,5,5,5,0,)

# %%
img_out = ct2d(img_tensor.unsqueeze(0))
img_out.shape
# Out:
# torch.Size([1, 3, 1390, 1810])

# %%
img_out_numpy = img_out.detach().numpy()
img_out_numpy.shape
# Out:
# (1, 3, 1390, 1810)

# %%
img_out_numpy[0].shape
# Out:
# (3, 1390, 1810)

# %%
plt.imshow(img_out_numpy[0][0])
